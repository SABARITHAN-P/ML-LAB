# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("spambase_csv_Kaggle.csv")

# %%
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_%3B  char_freq_%28  \
# ...

# %%
df.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     4601.000000        4601.000000    4601.000000   4601.000000
# mean         0.104553           0.213015       0.280656      0.065425
# std          0.305358           1.290575       0.504143      1.395151
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.420000      0.000000
# max          4.540000          14.280000       5.100000     42.810000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    4601.000000     4601.000000       4601.000000         4601.000000
# mean        0.312223        0.095901          0.114208            0.105295
# std         0.672513        0.273824          0.391441            0.401071
# ...

# %%
any(df["word_freq_mail"].isnull())
# Out:
# False

# %%
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_%3B  char_freq_%28  \
# ...

# %%
binary_cols = [col for col in df.columns if df[col].nunique() == 2]
print(binary_cols)
# Out:
# ['class']

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler, RobustScaler
from sklearn.model_selection import train_test_split
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
print(x)
print(y)
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
# X_std = StandardScaler().fit_transform(X)
# print(X_std)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     3680.000000        3680.000000    3680.000000   3680.000000
# mean         0.101427           0.203052       0.279457      0.055489
# std          0.297285           1.247236       0.507609      1.251653
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.410000      0.000000
# max          4.540000          14.280000       5.100000     42.730000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    3680.000000     3680.000000       3680.000000         3680.000000
# mean        0.305448        0.094834          0.107940            0.105103
# std         0.674729        0.275403          0.362757            0.407079
# ...

# %%
x_test.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count      921.000000         921.000000     921.000000    921.000000
# mean         0.117047           0.252823       0.285451      0.105125
# std          0.335563           1.450945       0.490288      1.861565
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.460000      0.000000
# max          4.000000          14.280000       4.340000     42.810000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count     921.000000      921.000000        921.000000          921.000000
# mean        0.339294        0.100163          0.139251            0.106059
# std         0.663257        0.267527          0.488997            0.376319
# ...

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB
model1= GaussianNB()
model2= BernoulliNB()

# %%
model1.fit(x_train, y_train)
model2.fit(x_train, y_train)
# Out:
# BernoulliNB()

# %%
y_predGNB = model1.predict(x_test)
y_predBNB = model2.predict(x_test)

# %%
from sklearn.metrics import (
accuracy_score, precision_score, recall_score, f1_score,
confusion_matrix, classification_report, roc_auc_score,
roc_curve, average_precision_score
)

# %% [markdown]
# # Model 1 Gaussian

# %%
confusion_matrix(y_test, y_predGNB)
# Out:
# array([[387, 144],
#        [ 21, 369]])

# %%
accuracy_score(y_test, y_predGNB)
# Out:
# 0.8208469055374593

# %%
precision_score(y_test, y_predGNB)
# Out:
# 0.7192982456140351

# %%
recall_score(y_test, y_predGNB)
# Out:
# 0.9461538461538461

# %%
f1_score(y_test, y_predGNB)
# Out:
# 0.8172757475083057

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_predGNB).ravel()
specificity = tn / (tn + fp)
fpr = fp / (fp + tn)

# %%
print("Specificity:", specificity)
# Out:
# Specificity: 0.7288135593220338

# %%
print("False Positive Rate:", fpr)
# Out:
# False Positive Rate: 0.2711864406779661

# %%
import time

start = time.time()
model1.fit(x_train, y_train)
train_time = time.time() - start

start = time.time()
y_pred = model1.predict(x_test)
pred_time = time.time() - start

# %%
print("Training Time:", train_time)
# Out:
# Training Time: 0.005968332290649414

# %%
print("Prediction Time:", pred_time)
# Out:
# Prediction Time: 0.001722097396850586

# %% [markdown]
# # Model 2 Bernouli

# %%
confusion_matrix(y_test, y_predBNB)
# Out:
# array([[499,  32],
#        [ 78, 312]])

# %%
accuracy_score(y_test, y_predBNB)
# Out:
# 0.8805646036916395

# %%
precision_score(y_test, y_predBNB)
# Out:
# 0.9069767441860465

# %%
recall_score(y_test, y_predBNB)
# Out:
# 0.8

# %%
f1_score(y_test, y_predBNB)
# Out:
# 0.8501362397820164

# %%
classification_report(y_test, y_predBNB)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.86      0.94      0.90       531\n           1       0.91      0.80      0.85       390\n\n    accuracy                           0.88       921\n   macro avg       0.89      0.87      0.88       921\nweighted avg       0.88      0.88      0.88       921\n'

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_predBNB).ravel()
specificity = tn / (tn + fp)
fpr = fp / (fp + tn)

# %%
print("Specificity:", specificity)
# Out:
# Specificity: 0.9397363465160076

# %%
print("False Positive Rate:", fpr)
# Out:
# False Positive Rate: 0.060263653483992465

# %%
import time

start = time.time()
model1.fit(x_train, y_train)
train_time = time.time() - start

start = time.time()
y_pred = model1.predict(x_test)
pred_time = time.time() - start

# %%
print("Training Time:", train_time)
# Out:
# Training Time: 0.007978677749633789

# %%
print("Prediction Time:", pred_time)
# Out:
# Prediction Time: 0.002738475799560547

# %% [markdown]
# ROC Curve

# %%
from sklearn.metrics import roc_curve, auc

y_prob = model1.predict_proba(x_test)[:,1]
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label="AUC = %.2f" % roc_auc)
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %% [markdown]
# KNN Hyperparameter Tuning (GridSearchCV)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

param_grid = {'n_neighbors': list(range(1,21))}
grid = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5)
grid.fit(x_train, y_train)

print("Best k:", grid.best_params_)
print("Best CV Accuracy:", grid.best_score_)
# Out:
# Best k: {'n_neighbors': 1}
# Best CV Accuracy: 0.8027173913043478

# %% [markdown]
# Accuracy vs k Plot

# %%
k_values = range(1,21)
acc = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    acc.append(knn.score(x_test, y_test))

plt.plot(k_values, acc)
plt.xlabel("k")
plt.ylabel("Accuracy")
plt.title("Accuracy vs k")
plt.show()

# %% [markdown]
# KDTree vs BallTree

# %%
knn_kd = KNeighborsClassifier(n_neighbors=grid.best_params_['n_neighbors'], algorithm='kd_tree')
knn_bt = KNeighborsClassifier(n_neighbors=grid.best_params_['n_neighbors'], algorithm='ball_tree')

knn_kd.fit(x_train, y_train)
knn_bt.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree', n_neighbors=1)
